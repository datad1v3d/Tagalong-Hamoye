# %%
import pandas as pd

# %%
import requests

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import yagmail

# %%
arr = [1,2,3]
 = np.array([arr])
ar
# Out:
# array([[1, 2, 3]])

# %%
e[[2,0,3,1],[2,1,0,2]] = array([18,11,19,15])
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 e[[2,0,3,1],[2,1,0,2]] = array([18,11,19,15])
#       2 e
#
# NameError: name 'array' is not defined

# %%
text = np.loadtxt('C:/Users/user/Documents/numpy text.txt')
text
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 text = np.loadtxt('C:/Users/user/Documents/numpy text.txt')
#       2 text
#
# File ~\AppData\Local\anaconda3\lib\site-packages\numpy\lib\npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339             converters=converters, skiplines=skiprows, usecols=usecols,
#    1340             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1341             max_rows=max_rows, quote=quotechar)
#    1343 return arr
#
# ...

# %%
data = pd.Series(['mon','tues','wed'])
data
# Out:
# 0     mon
# 1    tues
# 2     wed
# dtype: object

# %%
a = ['mon', 'tues', 'wed']

# %%
i = ['a', 'b', 'c']

# %% [markdown]
# . at and iat are used to retrieve single values such that at uses the column and row labels and iat uses indices. var(), skew(), kurt()

# %%
url = 'https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'

# %%
fuel_data = pd.read_csv(url, on_bad_lines = None)
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data['fuel_unit']=fuel_data['fuel_unit'].fillna(value = 'mcf')

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
fuel_df1
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_df2
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
g = sns.barplot(data = fuel_data, x = 'fuel_unit', y ='fuel_qty_burned')
g.set_yscale('log')
g.set_ylim(0, 1200000)
plt.xlabel('fuel unit')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1884\3154096147.py:3: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   g.set_ylim(0, 1200000)
# Text(0.5, 0, 'fuel unit')

# %%
sns.kdeplot(fuel_data['fuel_cost_per_unit_burned'], shade=True, color="b")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1884\1158879080.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(fuel_data['fuel_cost_per_unit_burned'], shade=True, color="b")
# <Axes: xlabel='fuel_cost_per_unit_burned', ylabel='Density'>
